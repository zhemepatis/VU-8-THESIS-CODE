# %%
from configs.data_set_config import DataSetConfig
from configs.data_split_config import DataSplitCofig
from configs.experiment_config import ExperimentConfig
from configs.k_nearest_neighbors_config import KNearestNeighborsConfig
from configs.noise_config import NoiseConfig
from experiment_runners.k_nearest_neighbors_runner import KNearestNeighborRunner
from utils.benchmark_funcs import BenchmarkFunctions

# %%
experiment_config :ExperimentConfig = ExperimentConfig(
    try_count = 100,
    verbose = True
)

# data set configuration
data_set_config :DataSetConfig = DataSetConfig(
    benchmark_function = BenchmarkFunctions.sphere_func,
    input_dimension = 4,
    component_domain = [-5, 5],
    data_set_size = 1_000
)

data_split_config :DataSplitCofig = DataSplitCofig(
    training_set_fraction = 0.85,
    validation_set_fraction = 0,
    test_set_fraction = 0.15
)

# k nearest neighbors configuration 
knn_config :KNearestNeighborsConfig = KNearestNeighborsConfig(
    neighbor_count = 3
)

# %% [markdown]
# # Experiments

# %%
neighbor_counts = [1, 3]
data_set_sizes = [1_000, 10_000, 100_000, 1_000_000, 10_000_000]

noise_configs = [
    None,
    NoiseConfig(
        mean = 0,
        std = 0.5
    ),
    NoiseConfig(
        mean = 0,
        std = 5
    )
]

# %%
for curr_neighbor_count in neighbor_counts:
    for curr_noise_config in noise_configs:
        for curr_data_set_size in data_set_sizes:
            
            print(f"EXPERIMENT PARAMETERS:")
            print(f"neighbor count = {curr_neighbor_count}")

            if curr_noise_config is not None:
                print(f"noise mean = {curr_noise_config.mean}")
                print(f"noise std = {curr_noise_config.std}")
            else:
                print("no noise applied")

            print(f"data set size = {curr_data_set_size:_}\n")

            # run experiment
            data_set_config :DataSetConfig = DataSetConfig(
                benchmark_function = BenchmarkFunctions.sphere_func,
                input_dimension = 4,
                component_domain = [-5, 5],
                data_set_size = curr_data_set_size
            )

            knn_config :KNearestNeighborsConfig = KNearestNeighborsConfig(
                neighbor_count = curr_neighbor_count
            ) 

            runner = KNearestNeighborRunner(
                experiment_config,
                data_set_config,
                data_split_config,
                curr_noise_config,
                knn_config
            )

            results = runner.run()

            # print results
            print(f"\nRESULTS: {results.min}\t{results.max}\t{results.mean}\t{results.std}")
            print("\n=====\n")
# Out:
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# no noise applied
# data set size = 1_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.05063068722761246	22.171874678568933	5.503611023505613	4.353623040291043
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# no noise applied
# data set size = 10_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.0029766747900609094	15.861997943812423	3.0531520309115847	2.4044587837885483
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# no noise applied
# data set size = 100_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.00020609052394953586	10.67248050419081	1.707046732223195	1.3295763448533067
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# no noise applied
# data set size = 1_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 1.0505476098245926e-05	6.593663364900606	0.9577940007780267	0.7405128620825466
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# no noise applied
# data set size = 10_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 4.6418300650330477e-07	4.027654592491044	0.5377095368854592	0.41385729593008846
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 0.5
# data set size = 1_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.05606355422609845	22.599828029397123	5.5022203687187705	4.384909684697887
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 0.5
# data set size = 10_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.0029171749141761348	16.427742566987778	3.0806072355747784	2.429463064982514
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 0.5
# data set size = 100_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.00019815943492207388	10.838255280205585	1.7552311439054054	1.3622426617422227
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 0.5
# data set size = 1_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 1.1935687627508963e-05	6.8894892132047945	1.0393209751226362	0.7977073351953627
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 0.5
# data set size = 10_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 8.293104471190915e-07	4.588074706045525	0.6708651574067521	0.5101664658764018
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 5
# data set size = 1_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.06691671128933313	26.60916881367366	6.8653511458646355	5.292616767002653
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 5
# data set size = 10_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.004882565671223565	23.124917991051873	5.05197172054313	3.835287321927902
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 5
# data set size = 100_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.000469921322415745	22.345883969540377	4.352151963086229	3.2882520421887222
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 5
# data set size = 1_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 3.608768516937477e-05	23.588501795779404	4.104503271943283	3.101384144538648
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 1
# noise mean = 0
# noise std = 5
# data set size = 10_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 3.5950035690746063e-06	25.62708997359175	4.0260697292926935	3.0415991189721945
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# no noise applied
# data set size = 1_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.03815571661836347	21.779227915651035	4.4549882032814345	3.956706426390201
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# no noise applied
# data set size = 10_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.002092086180994528	15.71865848592883	2.3071959279031877	1.9992663868602878
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# no noise applied
# data set size = 100_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.00014190183223850017	10.33083335782459	1.2385426240755306	1.046563329271995
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# no noise applied
# data set size = 1_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 6.070648543082535e-06	6.314265486803658	0.6761850924868799	0.5610324988083293
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# no noise applied
# data set size = 10_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 3.7706894970845897e-07	3.7988676257788154	0.373991360957279	0.30705491427789666
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 0.5
# data set size = 1_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.043068599843966805	22.799053205230088	4.461464410505143	3.94785856745601
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 0.5
# data set size = 10_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.002425983576951305	15.674090299396191	2.326558978994519	2.013473147058325
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 0.5
# data set size = 100_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.00011779866725080135	10.133050759055816	1.2602527558128964	1.055975674729729
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 0.5
# data set size = 1_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 7.077107698694185e-06	6.3354416772299045	0.7172710535798137	0.583785070747053
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 0.5
# data set size = 10_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 3.833763307703464e-07	3.9426946484888394	0.4424568526661527	0.34890382158151
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 5
# data set size = 1_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.05216207228426538	22.905226868245325	5.047397205410673	4.202107582478289
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 5
# data set size = 10_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.0035886255142348134	17.676891409254107	3.3089739436504586	2.600733269035564
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 5
# data set size = 100_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 0.0002933452906134737	14.415047835847956	2.632872330501624	2.0030444240189715
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 5
# data set size = 1_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 2.658503153456948e-05	14.055903477370318	2.4069555323438423	1.8203653821761867
#
# =====
#
# EXPERIMENT PARAMETERS:
# neighbor count = 3
# noise mean = 0
# noise std = 5
# data set size = 10_000_000
#
# Iteration 10 / 100
# Iteration 20 / 100
# Iteration 30 / 100
# Iteration 40 / 100
# Iteration 50 / 100
# Iteration 60 / 100
# Iteration 70 / 100
# Iteration 80 / 100
# Iteration 90 / 100
# Iteration 100 / 100
#
# RESULTS: 2.127532885047856e-06	14.855461736174018	2.335244457611067	1.764411042183371
#
# =====
