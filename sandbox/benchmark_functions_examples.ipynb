# %%
import matplotlib.pyplot as plt

import sys
import os
sys.path.append(os.path.abspath('..'))

from utils.benchmark_funcs import BenchmarkFunctions
from utils.data_generation_funcs import DataGenerationFunctions

# %%
input_dimention = 1
domain = [-5, 5]

data_set_size = 100_000

# %%
vectors = DataGenerationFunctions.generate_vectors(input_dimention, domain, data_set_size)
scalars = DataGenerationFunctions.generate_scalars(vectors, BenchmarkFunctions.rosenbrock_func)

# %%
plt.figure(figsize = (8, 6))

plt.scatter(
    vectors, 
    scalars, 
    s = 2, 
    c = "#007172"
)

plt.xlabel('x', fontsize = 14)
plt.ylabel('y', fontsize = 14)

plt.grid()

plt.show()
