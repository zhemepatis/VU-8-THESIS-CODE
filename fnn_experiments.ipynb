# %%
from configs.experiment_config import ExperimentConfig
from configs.data_set_config import DataSetConfig
from configs.noise_config import NoiseConfig
from configs.training_config import TrainingConfig
from configs.feedforward_nn_config import FeedforwardNNConfig

from experiment_runners.feedforward_nn_runner import FeedforwardNNRunner

from utils.benchmark_funcs import BenchmarkFunctions

# %%
experiment_config :ExperimentConfig = ExperimentConfig(
    try_count = 1,
    verbose = True
)

# data set configuration
data_set_config :DataSetConfig = DataSetConfig(
    # data generation configuration
    benchmark_function = BenchmarkFunctions.sphere_func,
    input_dimension = 4,
    component_domain = [-5, 5],
    data_set_size = 1_000,
    # data split configuration
    training_set_fraction = 0.7,
    validation_set_fraction = 0.15,
    test_set_fraction = 0.15
)

noise_config = None

# artificial neural netwokr model configuration 
fnn_config :FeedforwardNNConfig = FeedforwardNNConfig(
    input_neuron_num = data_set_config.input_dimension,
    h1_neuron_num = 70,
    output_neuron_num = 1
)

training_config :TrainingConfig = TrainingConfig(
    batch_size = 8,
    delta = 1e-6,
    epoch_limit = 150,
    patience_limit = 13,
    learning_rate = 0.01,
    verbose = True
)

# %%
runner = FeedforwardNNRunner(  
    experiment_config,
    data_set_config,
    noise_config,
    training_config,
    fnn_config
)

results = runner.run()
# Out:
# [10] Training loss: 0.001049 | Validation loss: 0.001949
# [20] Training loss: 0.000659 | Validation loss: 0.000715
# [30] Training loss: 0.000461 | Validation loss: 0.000558
# [40] Training loss: 0.000440 | Validation loss: 0.000387
# [50] Training loss: 0.000297 | Validation loss: 0.000133
# [60] Training loss: 0.000205 | Validation loss: 0.000162
# [70] Training loss: 0.000145 | Validation loss: 0.000135
# [80] Training loss: 0.000148 | Validation loss: 0.000369
# Early stopping at epoch 81 (no improvement for 13 epochs).
# Loaded best model with validation loss: 0.000067

# %%
print(f"Test set absolute error min: {results.min:.8f}")
print(f"Test set absolute error max: {results.max:.8f}")
print(f"Test set absolute error mean: {results.mean:.8f}")
print(f"Test set absolute error standard deviation: {results.std:.8f}")
# Out:
# Test set absolute error min: 0.00000000
# Test set absolute error max: 0.00001089
# Test set absolute error mean: 0.00000134
# Test set absolute error standard deviation: 0.00000130
